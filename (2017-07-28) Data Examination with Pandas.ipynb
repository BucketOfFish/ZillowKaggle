# %%
import csv
import sys
import StringIO
import os

prepath = "/Users/mattzhang/Dropbox/Projects/Data/Zillow/"
zillow = spark.read.options(header='true', inferSchema='true', delimiter=',').csv(prepath+"properties_2016.csv")

# %%
import pandas as pd
import csv
import sys
import StringIO
import os

prepath = "/Users/mattzhang/Dropbox/Projects/Data/Zillow/"
zillow = pd.read_csv(prepath+"properties_2016.csv")
# Out:
# /Users/mattzhang/py2_kernel/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2723: DtypeWarning: Columns (22,32,34,49,55) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
zillow.head()
# Out:
#    parcelid  airconditioningtypeid  architecturalstyletypeid  basementsqft  \
# 0  10754147                    NaN                       NaN           NaN
# 1  10759547                    NaN                       NaN           NaN
# 2  10843547                    NaN                       NaN           NaN
# 3  10859147                    NaN                       NaN           NaN
# 4  10879947                    NaN                       NaN           NaN
#
#    bathroomcnt  bedroomcnt  buildingclasstypeid  buildingqualitytypeid  \
# 0          0.0         0.0                  NaN                    NaN
# 1          0.0         0.0                  NaN                    NaN
# 2          0.0         0.0                  NaN                    NaN
# 3          0.0         0.0                  3.0                    7.0
# 4          0.0         0.0                  4.0                    NaN
#
#    calculatedbathnbr  decktypeid         ...           numberofstories  \
# ...

# %%
list(zillow)
# Out:
# ['parcelid',
#  'airconditioningtypeid',
#  'architecturalstyletypeid',
#  'basementsqft',
#  'bathroomcnt',
#  'bedroomcnt',
#  'buildingclasstypeid',
#  'buildingqualitytypeid',
#  'calculatedbathnbr',
#  'decktypeid',
#  'finishedfloor1squarefeet',
#  'calculatedfinishedsquarefeet',
#  'finishedsquarefeet12',
#  'finishedsquarefeet13',
#  'finishedsquarefeet15',
#  'finishedsquarefeet50',
#  'finishedsquarefeet6',
#  'fips',
#  'fireplacecnt',
#  'fullbathcnt',
#  'garagecarcnt',
#  'garagetotalsqft',
#  'hashottuborspa',
#  'heatingorsystemtypeid',
#  'latitude',
#  'longitude',
#  'lotsizesquarefeet',
#  'poolcnt',
#  'poolsizesum',
#  'pooltypeid10',
#  'pooltypeid2',
#  'pooltypeid7',
#  'propertycountylandusecode',
#  'propertylandusetypeid',
#  'propertyzoningdesc',
#  'rawcensustractandblock',
#  'regionidcity',
#  'regionidcounty',
#  'regionidneighborhood',
#  'regionidzip',
#  'roomcnt',
#  'storytypeid',
#  'threequarterbathnbr',
#  'typeconstructiontypeid',
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
for feature in list(zillow):
    print feature
    zillow[feature].hist()
    plt.show()
# Out:
# parcelid
# airconditioningtypeid
# architecturalstyletypeid
# basementsqft
# bathroomcnt
# bedroomcnt
# buildingclasstypeid
# buildingqualitytypeid
# calculatedbathnbr
# decktypeid
# finishedfloor1squarefeet
# calculatedfinishedsquarefeet
# finishedsquarefeet12
# finishedsquarefeet13
# finishedsquarefeet15
# finishedsquarefeet50
# finishedsquarefeet6
# fips
# fireplacecnt
# fullbathcnt
# garagecarcnt
# garagetotalsqft
# hashottuborspa
# heatingorsystemtypeid
# latitude
# longitude
# lotsizesquarefeet
# poolcnt
# poolsizesum
# pooltypeid10
# pooltypeid2
# pooltypeid7
# propertycountylandusecode
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-a4cd91c809e3> in <module>()
#       1 for feature in list(zillow):
#       2     print feature
# ----> 3     zillow[feature].hist()
#       4     plt.show()
#
# ...
